# %%
# !pip install pandas
import pandas as pd
from datetime import datetime as dt
from functools import reduce
from sqlalchemy import create_engine
import psycopg2 
from config import password, database, username

# %% [markdown]
# ## Imoprt csv's for mass shooting from 2013-2019

# %%
df_2014 = pd.read_csv("2014.csv")
df_2014.head()
# Out:
#    Incident ID      Incident Date       State  City Or County  \
# 0       271363  December 29, 2014   Louisiana     New Orleans
# 1       269679  December 27, 2014  California     Los Angeles
# 2       270036  December 27, 2014  California      Sacramento
# 3       269167  December 26, 2014    Illinois  East St. Louis
# 4       268598  December 24, 2014    Missouri     Saint Louis
#
#                                Address  # Killed  # Injured  Operations
# 0                  Poydras and Bolivar         0          4         NaN
# 1  8800 block of South Figueroa Street         1          3         NaN
# 2             4000 block of May Street         0          4         NaN
# 3          2500 block of Summit Avenue         1          3         NaN
# 4                        18th and Pine         1          3         NaN

# %%
df_2014 = df_2014[['Incident Date','State','# Killed','# Injured']].copy()
df_2014[['month','year']] = df_2014['Incident Date'].str.split(',',expand=True)

df_2014 = df_2014[['year','State','# Killed','# Injured']].copy()

df_2014.head()
# Out:
#     year       State  # Killed  # Injured
# 0   2014   Louisiana         0          4
# 1   2014  California         1          3
# 2   2014  California         0          4
# 3   2014    Illinois         1          3
# 4   2014    Missouri         1          3

# %%
df_clean14=df_2014.groupby('State').sum().sort_values(['# Killed'], ascending=False)
df_clean14.head()
# Out:
#             # Killed  # Injured
# State
# California        40        160
# Florida           31         65
# Texas             28         72
# Illinois          17        112
# Georgia           15         70

# %%
df_clean14.rename(columns={'year':'2014', '# Killed':'Killed_2014','year':'2014', 
                           '# Injured':'Injured_2014'}, inplace=True)

# %%
df_2015 = pd.read_csv("2015.csv")
df_2015.head()
# Out:
#    Incident ID      Incident Date         State City Or County  \
# 0       476321  December 31, 2015     Louisiana    New Orleans
# 1       473882  December 27, 2015     Tennessee        Jackson
# 2       472268  December 26, 2015  Pennsylvania   Philadelphia
# 3       471867  December 25, 2015       Florida   Jacksonville
# 4       471860  December 25, 2015       Alabama         Mobile
#
#                        Address  # Killed  # Injured  Operations
# 0  1900 block of Amelia Street         0          6         NaN
# 1                North Parkway         0          4         NaN
# 2           4210 Macalester St         0          4         NaN
# 3          Franklin and Odessa         0          4         NaN
# 4         785 Schillinger Rd S         0          4         NaN

# %%
df_2015 = df_2015[['Incident Date','State','# Killed','# Injured']].copy()
df_2015[['month','year']] = df_2015['Incident Date'].str.split(',',expand=True)

df_2015 = df_2015[['year','State','# Killed','# Injured']].copy()

df_2015.head()
# Out:
#     year         State  # Killed  # Injured
# 0   2015     Louisiana         0          6
# 1   2015     Tennessee         0          4
# 2   2015  Pennsylvania         0          4
# 3   2015       Florida         0          4
# 4   2015       Alabama         0          4

# %%
df_clean15=df_2015.groupby('State').sum().sort_values(['# Killed'], ascending=False)
df_clean15
# Out:
#                       # Killed  # Injured
# State
# Texas                       39         74
# California                  37        117
# Georgia                     27         71
# Florida                     20         94
# Ohio                        20         51
# South Carolina              20         31
# New York                    19         90
# Illinois                    17        100
# Arizona                     15         14
# Tennessee                   14         42
# Missouri                    12         49
# Oregon                      11         13
# Louisiana                   11         75
# Maryland                    11         49
# Indiana                     10         39
# Pennsylvania                 7         62
# North Carolina               7         52
# Minnesota                    6         18
# South Dakota                 6          0
# Wisconsin                    6          9
# Montana                      5          0
# Nebraska                     5         12
# New Jersey                   5         31
# Alabama                      4         13
# Vermont                      4          0
# New Mexico                   4          7
# Colorado                     4         16
# Michigan                     3         55
# Mississippi                  3          6
# Massachusetts                3         21
# Kansas                       2          2
# Kentucky                     2         18
# District of Columbia         2         11
# Arkansas                     2         14
# Virginia                     2         21
# Oklahoma                     1         22
# Connecticut                  1         13
# Nevada                       1          3
# Iowa                         1          8
# Rhode Island                 0          4
# Delaware                     0          6
# Washington                   0          4

# %%
df_clean15.rename(columns={'year':'2015', '# Killed':'Killed_2015','year':'2015', 
                           '# Injured':'Injured_2015'}, inplace=True)

# %%
df_2016 = pd.read_csv("2016.csv")
df_2016.head()
# Out:
#    Incident ID      Incident Date        State     City Or County  \
# 0       740447  December 31, 2016      Georgia  Lenox (El Dorado)
# 1       738749  December 31, 2016        Texas            Houston
# 2       738041  December 30, 2016         Ohio          Mansfield
# 3       738576  December 30, 2016  Connecticut        Wallingford
# 4       736690  December 28, 2016      Georgia           Columbus
#
#               Address  # Killed  # Injured  Operations
# 0     27 Briarwood Ct         2          2         NaN
# 1  3704 Fannin Street         1          3         NaN
# 2  3230 Possum Run Rd         0          5         NaN
# 3    95 S Turnpike Rd         2          3         NaN
# 4    2914 10th Street         1          4         NaN

# %%
df_2016 = df_2016[['Incident Date','State','# Killed','# Injured']].copy()
df_2016[['month','year']] = df_2016['Incident Date'].str.split(',',expand=True)

df_2016 = df_2016[['year','State','# Killed','# Injured']].copy()

df_2016.head()
# Out:
#     year        State  # Killed  # Injured
# 0   2016      Georgia         2          2
# 1   2016        Texas         1          3
# 2   2016         Ohio         0          5
# 3   2016  Connecticut         2          3
# 4   2016      Georgia         1          4

# %%
df_clean16=df_2016.groupby('State').sum().sort_values(['# Killed'], ascending=False)
df_clean16.head()
# Out:
#             # Killed  # Injured
# State
# Florida           81        186
# Texas             42        115
# California        34        194
# Illinois          32        158
# Georgia           24         56

# %%
df_clean16.rename(columns={'year':'2016', '# Killed':'Killed_2016','year':'2016', 
                           '# Injured':'Injured_2016'}, inplace=True)
#index_df =df_clean16.rename(index={"State": 'state'})

#index_df

# %%
df_2017 = pd.read_csv("2017.csv")
df_2017.head()
# Out:
#    Incident ID      Incident Date       State               City Or County  \
# 0      1017372  December 31, 2017    Colorado  Littleton (Highlands Ranch)
# 1      1017422  December 31, 2017    Illinois                      Chicago
# 2      1018118  December 31, 2017  New Jersey                  Long Branch
# 3      1015666  December 27, 2017      Nevada                    Las Vegas
# 4      1015336  December 26, 2017     Florida                        Miami
#
#                     Address  # Killed  # Injured  Operations
# 0     3404 E County Line Rd         2          6         NaN
# 1            2335 Howard St         0          4         NaN
# 2               635 Wall St         4          0         NaN
# 3         3750 E Bonanza Rd         2          2         NaN
# 4  NW 18th Ave and 86th Ter         0          5         NaN

# %%
df_2017 = df_2017[['Incident Date','State','# Killed','# Injured']].copy()
df_2017[['month','year']] = df_2017['Incident Date'].str.split(',',expand=True)

df_2017 = df_2017[['year','State','# Killed','# Injured']].copy()

df_2017.head()
# Out:
#     year       State  # Killed  # Injured
# 0   2017    Colorado         2          6
# 1   2017    Illinois         0          4
# 2   2017  New Jersey         4          0
# 3   2017      Nevada         2          2
# 4   2017     Florida         0          5

# %%
df_clean17=df_2017.groupby('State').sum().sort_values(['# Killed'], ascending=False)
df_clean17.head()
# Out:
#              # Killed  # Injured
# State
# Nevada             61        443
# Texas              59         91
# California         37        149
# Illinois           28        149
# Mississippi        24         41

# %%
df_clean17.rename(columns={'year':'2017', '# Killed':'Killed_2017','year':'2017', 
                           '# Injured':'Injured_2017'}, inplace=True)

# %%
df_2018 = pd.read_csv("2018.csv")
df_2018.head()
# Out:
#    Incident ID      Incident Date      State City Or County  \
# 0      1289686  December 31, 2018       Ohio      Cleveland
# 1      1288376  December 29, 2018       Ohio           Lima
# 2      1287286  December 28, 2018   Missouri  Saint Charles
# 3      1284586  December 24, 2018  Louisiana        Lutcher
# 4      1283229  December 23, 2018   Missouri    Springfield
#
#              Address  # Killed  # Injured  Operations
# 0   4462 Denison Ave         3          2         NaN
# 1      904 S Main St         1          3         NaN
# 2   150 Whetstone Dr         4          1         NaN
# 3       2176 Main St         2          2         NaN
# 4  1042 W College St         1          6         NaN

# %%
df_2018 = df_2018[['Incident Date','State','# Killed','# Injured']].copy()
df_2018[['month','year']] = df_2018['Incident Date'].str.split(',',expand=True)

df_2018 = df_2018[['year','State','# Killed','# Injured']].copy()

df_2018.head()
# Out:
#     year      State  # Killed  # Injured
# 0   2018       Ohio         3          2
# 1   2018       Ohio         1          3
# 2   2018   Missouri         4          1
# 3   2018  Louisiana         2          2
# 4   2018   Missouri         1          6

# %%
df_clean18=df_2018.groupby('State').sum().sort_values(['# Killed'], ascending=False)
df_clean18.head()
# Out:
#               # Killed  # Injured
# State
# California          50        136
# Florida             49        130
# Pennsylvania        35         63
# Texas               28         59
# Illinois            21        150

# %%
df_clean18.rename(columns={'year':'2018', '# Killed':'Killed_2018','year':'2018', 
                           '# Injured':'Injured_2018'}, inplace=True)
df_clean18.head()
# Out:
#               Killed_2018  Injured_2018
# State
# California             50           136
# Florida                49           130
# Pennsylvania           35            63
# Texas                  28            59
# Illinois               21           150

# %%
df_2019 = pd.read_csv("2019.csv")
df_2019.head()
# Out:
#    Incident ID      Incident Date       State City Or County  \
# 0      1582816  December 29, 2019    Illinois       Danville
# 1      1582197  December 29, 2019    New York        Buffalo
# 2      1583444  December 29, 2019  California          Ceres
# 3      1581590  December 27, 2019  California        Modesto
# 4      1581103  December 27, 2019       Texas        Houston
#
#                       Address  # Killed  # Injured  Operations
# 0  1803 block of Westview Ave         0          5         NaN
# 1   50 block of Henrietta Ave         1          3         NaN
# 2   800 block of Allacante Dr         0          5         NaN
# 3    1900 block of Vernon Ave         1          3         NaN
# 4       500 block of Smart St         2          7         NaN

# %%
df_2019 = df_2019[['Incident Date','State','# Killed','# Injured']].copy()
df_2019[['month','year']] = df_2019['Incident Date'].str.split(',',expand=True)

df_2019 = df_2019[['year','State','# Killed','# Injured']].copy()

df_2019.head()
# Out:
#     year       State  # Killed  # Injured
# 0   2019    Illinois         0          5
# 1   2019    New York         1          3
# 2   2019  California         0          5
# 3   2019  California         1          3
# 4   2019       Texas         2          7

# %%
df_clean19=df_2019.groupby('State').sum().sort_values(['# Killed'], ascending=False)
df_clean19.head()
# Out:
#             # Killed  # Injured
# State
# Texas             73        142
# California        65        193
# Illinois          28        182
# Virginia          21         41
# Missouri          20         60

# %%
df_clean19.rename(columns={'year':'2019', '# Killed':'Killed_2019','year':'2019', 
                           '# Injured':'Injured_2019'}, inplace=True)

# %%
df_list = [df_clean16, df_clean17, df_clean18, df_clean19 ]

# %%
mass_shootings_all = reduce(lambda  left,right: pd.merge(left,right,on=['State'],
                                            how='outer'), df_list)
mass_shootings_all

mass_shootings_all.fillna(0).head()
# Out:
#             Killed_2016  Injured_2016  Killed_2017  Injured_2017  Killed_2018  \
# State
# Florida            81.0         186.0         21.0         101.0         49.0
# Texas              42.0         115.0         59.0          91.0         28.0
# California         34.0         194.0         37.0         149.0         50.0
# Illinois           32.0         158.0         28.0         149.0         21.0
# Georgia            24.0          56.0          9.0          36.0          3.0
#
#             Injured_2018  Killed_2019  Injured_2019
# State
# Florida            130.0         20.0          54.0
# Texas               59.0         73.0         142.0
# California         136.0         65.0         193.0
# Illinois           150.0         28.0         182.0
# Georgia             33.0         16.0          74.0

# %% [markdown]
# ## import gun background check per state

# %%
df_b_checks = pd.read_csv("nics-firearm-background-checks.csv")
df_b_checks.head()

df_b_checks.rename(columns={'state':'State'}, inplace=True)

# %%
df_b_checks.dropna(inplace=True)
df_b_checks[['year','month']] = df_b_checks['month'].str.split('-',expand=True)

df_b_checks
# Out:
#      month          State   permit  permit_recheck  handgun  long_gun   other  \
# 0       03        Alabama  31205.0           606.0  34897.0   17850.0  1583.0
# 1       03         Alaska    143.0             4.0   4657.0    3819.0   487.0
# 2       03        Arizona   5685.0           958.0  46377.0   19346.0  2433.0
# 3       03       Arkansas   2424.0           673.0  15304.0    8968.0   600.0
# 4       03     California  27792.0             0.0  81543.0   48616.0  5041.0
# ...    ...            ...      ...             ...      ...       ...     ...
# 2415    08       Virginia    776.0             0.0  21108.0   15802.0   978.0
# 2416    08     Washington  14063.0            33.0  15083.0   11376.0  1622.0
# 2417    08  West Virginia   1948.0             0.0   6916.0    5283.0   243.0
# 2418    08      Wisconsin  25551.0             0.0  14764.0   12079.0   709.0
# 2419    08        Wyoming    906.0             3.0   1721.0    2079.0   105.0
#
#       multiple  admin  prepawn_handgun  ...  rentals_handgun  \
# 0         1744    0.0             36.0  ...              0.0
# 1          386    0.0              0.0  ...              0.0
# 2         4846    0.0             18.0  ...              0.0
# 3          885    4.0             27.0  ...              0.0
# 4            0    0.0              0.0  ...              0.0
# ...        ...    ...              ...  ...              ...
# 2415         0    0.0              0.0  ...              0.0
# 2416       606    8.0              6.0  ...              0.0
# 2417       345   14.0              9.0  ...              0.0
# 2418        43    0.0              0.0  ...              0.0
# 2419        96    2.0              0.0  ...              0.0
#
#       rentals_long_gun  private_sale_handgun  private_sale_long_gun  \
# 0                  0.0                  42.0                   23.0
# 1                  0.0                  14.0                   13.0
# 2                  0.0                  21.0                   11.0
# 3                  0.0                  11.0                   10.0
# 4                  0.0                   0.0                    0.0
# ...                ...                   ...                    ...
# 2415               0.0                   0.0                    0.0
# 2416               0.0                 503.0                  444.0
# 2417               0.0                   3.0                    1.0
# 2418               0.0                   4.0                    5.0
# 2419               0.0                   0.0                    0.0
#
#       private_sale_other  return_to_seller_handgun  return_to_seller_long_gun  \
# 0                    8.0                       2.0                        2.0
# 1                    0.0                       0.0                        0.0
# 2                    5.0                       0.0                        0.0
# 3                    3.0                       1.0                        0.0
# 4                    0.0                       0.0                        0.0
# ...                  ...                       ...                        ...
# 2415                 0.0                       0.0                        0.0
# 2416                23.0                      11.0                        4.0
# 2417                 0.0                       0.0                        2.0
# 2418                 0.0                       0.0                        0.0
# 2419                 0.0                       0.0                        0.0
#
#       return_to_seller_other  totals  year
# 0                        0.0   92652  2020
# 1                        0.0    9939  2020
# 2                        0.0   82771  2020
# 3                        2.0   31651  2020
# 4                        0.0  164497  2020
# ...                      ...     ...   ...
# 2415                     0.0   38667  2016
# 2416                     1.0   46645  2016
# 2417                     0.0   17315  2016
# 2418                     0.0   53689  2016
# 2419                     0.0    5295  2016
#
# [2420 rows x 28 columns]

# %%
df_bc_clean = df_b_checks[['year','State','permit']].copy()
df_bc_clean
# Out:
#       year          State   permit
# 0     2020        Alabama  31205.0
# 1     2020         Alaska    143.0
# 2     2020        Arizona   5685.0
# 3     2020       Arkansas   2424.0
# 4     2020     California  27792.0
# ...    ...            ...      ...
# 2415  2016       Virginia    776.0
# 2416  2016     Washington  14063.0
# 2417  2016  West Virginia   1948.0
# 2418  2016      Wisconsin  25551.0
# 2419  2016        Wyoming    906.0
#
# [2420 rows x 3 columns]

# %% [markdown]
# ## Combine cleandf mass shooting with clean df background

# %%
b_checks_groupby = df_bc_clean.groupby(['State','year']).sum().sort_values(['permit'],\
                    ascending=False)
b_checks_groupby


b_checks_groupby = b_checks_groupby.reset_index() 

b_checks_groupby
# Out:
#             State  year     permit
# 0        Kentucky  2018  4655016.0
# 1        Kentucky  2017  4362693.0
# 2        Kentucky  2019  1782427.0
# 3        Kentucky  2016  1296727.0
# 4      California  2017   689851.0
# ..            ...   ...        ...
# 270       Vermont  2019        0.0
# 271       Vermont  2020        0.0
# 272  Rhode Island  2016        0.0
# 273   Puerto Rico  2020        0.0
# 274    New Jersey  2017        0.0
#
# [275 rows x 3 columns]

# %%
permit_2016 = b_checks_groupby.loc[b_checks_groupby[('year')] == '2016']

permit_2016.rename(columns={'permit':'permit_2016', 'year': 'year_2016'}, inplace=True)

# permit_2016.reset_index()

permit_2017 = b_checks_groupby.loc[b_checks_groupby[('year')] == '2017']

permit_2017.rename(columns={'permit':'permit_2017', 'year': 'year_2017'}, inplace=True)

# permit_2017.reset_index()

permit_2018 = b_checks_groupby.loc[b_checks_groupby[('year')] == '2018']

permit_2018.rename(columns={'permit':'permit_2018', 'year': 'year_2018'}, inplace=True)



# permit_2018.reset_index()

permit_2019 = b_checks_groupby.loc[b_checks_groupby[('year')] == '2019']

permit_2019.rename(columns={'permit':'permit_2019', 'year': 'year_2019'}, inplace=True)
# permit_2019.reset_index().head()

permit_2016 


permit_list = [permit_2016, permit_2017, permit_2018, permit_2019 ]
for df in permit_list:
    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 3 to 272
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        55 non-null     object
#  1   year_2016    55 non-null     object
#  2   permit_2016  55 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 1 to 274
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        55 non-null     object
#  1   year_2017    55 non-null     object
#  2   permit_2017  55 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 0 to 264
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        55 non-null     object
#  1   year_2018    55 non-null     object
#  2   permit_2018  55 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 2 to 270
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        55 non-null     object
#  1   year_2019    55 non-null     object
#  2   permit_2019  55 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.7+ KB
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
permit_list = [permit_2016, permit_2017, permit_2018, permit_2019 ]

# permit_list

permit_all = reduce(lambda  left,right: pd.merge(left,right,on=['State'],
                                            how='outer'), permit_list)
permit_all

permit_all = permit_all.fillna(0)

# df_bc_clean = permit_all[['State','permit_x', 'permit_y']].copy()

# df_bc_clean

len(permit_all)
# Out:
# 55

# %%
mass_shootings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43 entries, Florida to Wyoming
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Killed_2016   37 non-null     float64
#  1   Injured_2016  37 non-null     float64
#  2   Killed_2017   39 non-null     float64
#  3   Injured_2017  39 non-null     float64
#  4   Killed_2018   37 non-null     float64
#  5   Injured_2018  37 non-null     float64
#  6   Killed_2019   40 non-null     float64
#  7   Injured_2019  40 non-null     float64
# dtypes: float64(8)
# memory usage: 3.0+ KB

# %%
permit_clean = permit_all[['State', 'permit_2016', 'permit_2017', 'permit_2018', 'permit_2019']].copy()
# permit_renamed = permit_all.rename(columns={'permit_x':'permit_2016', 'permit_y':'permit_2017','permit_x':'permit_2018', 
#                             'permit_y':'permit_2019'}, inplace=True)

# permit_renamed = permit_all[['State','permit_2016', 'permit_2017', 'permit_2018', 'permit_2019']].copy()

# permit_renamed

# permit_clean.info()

permit_clean.head()
# Out:
#           State  permit_2016  permit_2017  permit_2018  permit_2019
# 0      Kentucky    1296727.0    4362693.0    4655016.0    1782427.0
# 1    California     313395.0     689851.0     497069.0     431844.0
# 2       Indiana     187159.0     389171.0     474341.0     227637.0
# 3     Minnesota     163323.0     443975.0     351809.0     129788.0
# 4  Pennsylvania     143061.0     316614.0     305451.0     273455.0

# %%
mass_shooting_df = permit_clean.merge(mass_shootings_all, how="left", on="State" )
mass_shooting_df.fillna(0)
# Out:
#                    State  permit_2016  permit_2017  permit_2018  permit_2019  \
# 0               Kentucky    1296727.0    4362693.0    4655016.0    1782427.0
# 1             California     313395.0     689851.0     497069.0     431844.0
# 2                Indiana     187159.0     389171.0     474341.0     227637.0
# 3              Minnesota     163323.0     443975.0     351809.0     129788.0
# 4           Pennsylvania     143061.0     316614.0     305451.0     273455.0
# 5         North Carolina     138974.0     299025.0     303492.0     299605.0
# 6                  Texas     137338.0     317766.0     420120.0     348122.0
# 7              Wisconsin     135402.0     182395.0     131991.0     102078.0
# 8                Florida     129447.0     236486.0     225353.0     202456.0
# 22          27.0          2.0          20.0
# 23          16.0          0.0           4.0
# 24          17.0          3.0          20.0
# 25           0.0          0.0           0.0
# 26          53.0          7.0          43.0
# 27          49.0         20.0         106.0
# 28          31.0         12.0          85.0
# 29           0.0          0.0           0.0
# 30          51.0         20.0          60.0
# 31          15.0          1.0          14.0
# 32          17.0          8.0          21.0
# 33          11.0          5.0          16.0
# 34           0.0          0.0           0.0
# 35           0.0          5.0           4.0
# 36           0.0          0.0           0.0
# 37           0.0          0.0           0.0
# 38           4.0          8.0          18.0
# 39           0.0          0.0           0.0
# 40          17.0         21.0          41.0
# 41           0.0          2.0           2.0
# 42           0.0          0.0          10.0
# 43           0.0          0.0           0.0
# 44           0.0          0.0           5.0
# 45           0.0          0.0           0.0
# 46           0.0          0.0           0.0
# 47          23.0          4.0          28.0
# 48           0.0          0.0           0.0
# 49           0.0          0.0           0.0
# 50          19.0          5.0          12.0
# 51          54.0         12.0          47.0
# 52           0.0          0.0           0.0
# 53           0.0          0.0           0.0
# 54           0.0          0.0           0.0

# %%
reordered_df = mass_shooting_df[['State','permit_2016', 'Injured_2016', 'Killed_2016', 'permit_2017', 'Injured_2017', 'Killed_2017','permit_2018', 'Injured_2018', 'Killed_2018','permit_2019', 'Injured_2019', 'Killed_2019']]
final_df = reordered_df.fillna(0)

final_df.rename(columns={'State':'state', 'Injured_2016': 'injured_2016', 'Killed_2016': 'killed_2016','Injured_2017': 'injured_2017', 'Killed_2017': 'killed_2017','Injured_2018': 'injured_2018', 'Killed_2018': 'killed_2018', 'Injured_2019': 'injured_2019', 'Killed_2019': 'killed_2019'}, inplace=True)


final_df.head()
# Out:
#           state  permit_2016  injured_2016  killed_2016  permit_2017  \
# 0      Kentucky    1296727.0           6.0          4.0    4362693.0
# 1    California     313395.0         194.0         34.0     689851.0
# 2       Indiana     187159.0          25.0          8.0     389171.0
# 3     Minnesota     163323.0          24.0          1.0     443975.0
# 4  Pennsylvania     143061.0          32.0         16.0     316614.0
#
#    injured_2017  killed_2017  permit_2018  injured_2018  killed_2018  \
# 0          26.0          2.0    4655016.0          25.0          7.0
# 1         149.0         37.0     497069.0         136.0         50.0
# 2          29.0          4.0     474341.0          22.0          7.0
# 3          13.0          4.0     351809.0          13.0          1.0
# 4          63.0          8.0     305451.0          63.0         35.0
#
#    permit_2019  injured_2019  killed_2019
# 0    1782427.0          18.0          6.0
# 1     431844.0         193.0         65.0
# 2     227637.0          49.0          6.0
# 3     129788.0          12.0          1.0
# 4     273455.0          84.0         13.0

# %%
#engine = create_engine(f"postgresql://{username}:{password}@localhost:5432/{database}")
#rds_connection_string = "postgres:postgres@localhost:5432/mass_shooting"

#engine = create_engine(f'postgresql://{rds_connection_string}')
# Create Database Connection with sql
engine = create_engine(f"postgresql://{username}:{password}@localhost:5432/{database}")
conn = engine.connect()

# %%
engine.table_names()
# Out:
# /var/folders/qt/z1139kj16rq91qs03f19sz2c0000gn/T/ipykernel_94201/4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['mass_shooting']

# %%
final_df.to_sql(name='mass_shooting', con=engine, if_exists='replace', index=False)
